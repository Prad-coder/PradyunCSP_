# %% [raw]
# ---
# layout: post
# title: Color Codes and Base 64 Hacks
# categories: [Tri 3 Team Teach Hacks]
# type: issues
# comments: true
# ---

# %% [markdown]
# ## Popcorn Hack 1
#
# PNG (Portable Network Graphics) — It supports high-quality images and full transparency, making it ideal for logos with transparent backgrounds.
#
# ## Popcorn Hack 2
#
# JPEG (Joint Photographic Experts Group) — It uses lossy compression, reducing file size by discarding image data, which can lower quality.
#
# ## Popcorn Hack 3
#
# GIF (Graphics Interchange Format) — It supports basic animations and is often used for short, looping meme content.
#
# ## Popcorn Hack 4
#
# U1Q=
#
# ## Homework Hack 1
#
# <style>
#   .color-block {
#     height: 100px;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     font-size: 1.5rem;
#   }
#   .white-text { color: white; }
#   .black-text { color: black; }
# </style>
#
# <div class="color-block white-text" style="background-color: blue;">Blue</div>
# <div class="color-block white-text" style="background-color: red;">Red</div>
# <div class="color-block white-text" style="background-color: black;">Black</div>
# <div class="color-block black-text" style="background-color: yellow;">Yellow</div>
# <div class="color-block black-text" style="background-color: white;">White</div>
#
# ## Homework Hack 2
#
# <style>
#   .image-container {
#     display: flex;
#     justify-content: center;
#     margin-top: 50px;
#   }
#   img {
#     max-width: 300px;
#     border: 2px solid #333;
#     border-radius: 8px;
#   }
# </style>
#
# <div class="image-container">
#   <img src="data:image/jpeg;base64,..." alt="Inline Image">
# </div>
