# %% [raw]
# ---
# layout: post
# title: Cookie Clicker
# description:  Click some cookies!
# type: issues
# comments: true
# ---

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Cookie Clicker Game</title>
#     <link rel="stylesheet" href="styles.css">
# </head>
# <body>
#     <div class="container">
#         <div class="cookie-section">
#             <button id="cookie" onclick="buttonClicked()">
#                 <img src="{{site.baseurl}}/images/CookieClickerImage-removebg-preview (1).png" alt="Cookie">
#             </button>
#             <p id="cookie-count">Cookies: 0</p>
#         </div>
#         <div class="upgrade-section">
#             <button id="upgrade">Buy Upgrade (Cost: 10 cookies)</button>
#             <p id="upgrade-count">Upgrades: 0</p>
#         </div>
#     </div>
#     <!-- Add the audio element here -->
#     <audio id="click-sound" src="068243_crunchy-cookie-eatingwav-81661.mp3"></audio>
#     <script>
#         // Initialize game variables
#         let cookieCount = 0;
#         let upgradeCount = 0;
#         let upgradeCost = 10;
#         let baseClickInterval = 1000; // Base interval time in milliseconds (1 second)
#         let clickIntervalId = null;
#         let cookiesPerInterval = 1; // Number of cookies clicked per interval
#         const cookieButton = document.getElementById('cookie');
#         const cookieCountDisplay = document.getElementById('cookie-count');
#         const upgradeButton = document.getElementById('upgrade');
#         const upgradeCountDisplay = document.getElementById('upgrade-count');
#         const clickSound = document.getElementById('click-sound'); // Get the audio element
#         clickSound.volume = 1; // Set volume to maximum
#         clickSound.muted = false; // Ensure audio is not muted
#         // Update the cookie count display
#         function updateCookieCount() {
#             cookieCountDisplay.textContent = `Cookies: ${cookieCount}`;
#         }
#         // Update the upgrade count display
#         function updateUpgradeCount() {
#             upgradeCountDisplay.textContent = `Upgrades: ${upgradeCount}`;
#         }
#         // Play sound and update cookie count on button click
#         function buttonClicked() {
#             clickSound.play(); // Play the sound
#             cookieCount++;
#             updateCookieCount();
#         }
#         // Cookie button click event
#         cookieButton.addEventListener('click', buttonClicked);
#         // Upgrade button click event
#         upgradeButton.addEventListener('click', () => {
#             if (cookieCount >= upgradeCost) {
#                 cookieCount -= upgradeCost;
#                 upgradeCount++;
#                 updateCookieCount();
#                 updateUpgradeCount();
#                 // Clear any existing interval
#                 if (clickIntervalId) {
#                     clearInterval(clickIntervalId);
#                 }
#                 // Start a new interval for automatic clicking
#                 clickIntervalId = setInterval(clickCookies, baseClickInterval);
#                 // Increase the number of cookies clicked per interval with each upgrade
#                 cookiesPerInterval += 1;
#                 // Increase the cost for subsequent upgrades
#                 upgradeCost += 10; // Adjust cost increment as needed
#                 upgradeButton.textContent = `Buy Upgrade (Cost: ${upgradeCost} cookies)`;
#             } else {
#                 alert('Not enough cookies to buy an upgrade!');
#             }
#         });
#     </script>
# </body>
# </html>
